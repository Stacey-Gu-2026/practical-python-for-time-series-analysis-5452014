# %% [markdown]
# # Join and preprocess multiple time series data

# %% [markdown]
# ## Load data

# %%
path = '../../data/data_FRED/CORESTICKM159SFRBATL.csv'

# %%
import pandas as pd

pdf = pd.read_csv(filepath_or_buffer=path, index_col='observation_date')

# %%
pdf.plot(title='FRED Data - first PDF (Inflation)')

# %% [markdown]
# ## Parse dates to join time series

# %%
path = '../../data/data_FRED/CORESTICKM159SFRBATL.csv'
pdf1 = pd.read_csv(filepath_or_buffer=path, 
                   index_col='observation_date',
                   parse_dates=True)

pdf1
# Out:
#                   CORESTICKM159SFRBATL
# observation_date
# 1968-01-01                    3.651861
# 1968-02-01                    3.673819
# ...                                ...
# 2026-03-01                    2.929321
# 2026-04-01                    3.038932
#
# [700 rows x 1 columns]

# %%
path = '../../data/data_FRED/MORTGAGE30US.csv'
pdf2 = pd.read_csv(filepath_or_buffer=path, 
                   index_col='observation_date',
                   parse_dates=True)

pdf2
# Out:
#                   MORTGAGE30US
# observation_date
# 1971-04-02                7.33
# 1971-04-09                7.31
# ...                        ...
# 2026-05-07                6.37
# 2026-05-14                6.36
#
# [2877 rows x 1 columns]

# %%
pdf1.index
# Out:
# DatetimeIndex(['1968-01-01', '1968-02-01', '1968-03-01', '1968-04-01',
#                '1968-05-01', '1968-06-01', '1968-07-01', '1968-08-01',
#                '1968-09-01', '1968-10-01',
#                ...
#                '2025-07-01', '2025-08-01', '2025-09-01', '2025-10-01',
#                '2025-11-01', '2025-12-01', '2026-01-01', '2026-02-01',
#                '2026-03-01', '2026-04-01'],
#               dtype='datetime64[ns]', name='observation_date', length=700, freq=None)

# %%
pdf_join = pd.concat([pdf1, pdf2], axis=1, )
pdf_join.tail(50).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_af9a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af9a5_level0_col0" class="col_heading level0 col0" >CORESTICKM159SFRBATL</th>
#       <th id="T_af9a5_level0_col1" class="col_heading level0 col1" >MORTGAGE30US</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >observation_date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af9a5_level0_row0" class="row_heading level0 row0" >2025-08-01 00:00:00</th>
#       <td id="T_af9a5_row0_col0" class="data row0 col0" >3.430945</td>
#       <td id="T_af9a5_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_af9a5_level0_row1" class="row_heading level0 row1" >2025-08-07 00:00:00</th>
#       <td id="T_af9a5_row1_col0" class="data row1 col0" >nan</td>
# ...

# %%
pdf_join.plot(title='FRED Data - Outer Join')

# %% [markdown]
# ## Inner join vs outer join

# %%
pdf_join_inner = pd.concat([pdf1, pdf2], axis=1, join='inner')
pdf_join_inner.tail(10).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_51f04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51f04_level0_col0" class="col_heading level0 col0" >CORESTICKM159SFRBATL</th>
#       <th id="T_51f04_level0_col1" class="col_heading level0 col1" >MORTGAGE30US</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >observation_date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51f04_level0_row0" class="row_heading level0 row0" >2019-08-01 00:00:00</th>
#       <td id="T_51f04_row0_col0" class="data row0 col0" >2.630398</td>
#       <td id="T_51f04_row0_col1" class="data row0 col1" >3.750000</td>
#     </tr>
#     <tr>
#       <th id="T_51f04_level0_row1" class="row_heading level0 row1" >2020-10-01 00:00:00</th>
#       <td id="T_51f04_row1_col0" class="data row1 col0" >1.749610</td>
# ...

# %%
pdf_join_inner.plot(title="FRED Data - Inner Join")

# %% [markdown]
# ## Interpolate missing values

# %%
pdf_join = pd.concat([pdf1, pdf2], axis=1, join='outer')
pdf_join.tail(20).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_89b5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89b5f_level0_col0" class="col_heading level0 col0" >CORESTICKM159SFRBATL</th>
#       <th id="T_89b5f_level0_col1" class="col_heading level0 col1" >MORTGAGE30US</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >observation_date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89b5f_level0_row0" class="row_heading level0 row0" >2026-01-22 00:00:00</th>
#       <td id="T_89b5f_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_89b5f_row0_col1" class="data row0 col1" >6.090000</td>
#     </tr>
#     <tr>
#       <th id="T_89b5f_level0_row1" class="row_heading level0 row1" >2026-01-29 00:00:00</th>
#       <td id="T_89b5f_row1_col0" class="data row1 col0" >nan</td>
# ...

# %%
pdf_join_interpl = pdf_join.interpolate(method='linear')
pdf_join_interpl.tail(20).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_d4edf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4edf_level0_col0" class="col_heading level0 col0" >CORESTICKM159SFRBATL</th>
#       <th id="T_d4edf_level0_col1" class="col_heading level0 col1" >MORTGAGE30US</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >observation_date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4edf_level0_row0" class="row_heading level0 row0" >2026-01-22 00:00:00</th>
#       <td id="T_d4edf_row0_col0" class="data row0 col0" >2.934246</td>
#       <td id="T_d4edf_row0_col1" class="data row0 col1" >6.090000</td>
#     </tr>
#     <tr>
#       <th id="T_d4edf_level0_row1" class="row_heading level0 row1" >2026-01-29 00:00:00</th>
#       <td id="T_d4edf_row1_col0" class="data row1 col0" >2.919078</td>
# ...

# %%
pdf_join_interpl.plot(title = 'FRED Data - Linear Interpolated')

# %% [markdown]
# ## Iterate for seamless loading of multiple datasets

# %%
paths = [
    '../../data/data_FRED/CORESTICKM159SFRBATL.csv',
    '../../data/data_FRED/MORTGAGE30US.csv',
    '../../data/data_FRED/FEDFUNDS.csv',
    '../../data/data_FRED/T10YIE.csv',
    '../../data/data_FRED/UNRATE.csv'
]

pdfs = []
for path in paths:
    pdf_i = pd.read_csv(path, index_col=0, parse_dates=True)
    pdfs.append(pdf_i)
pdfs
# Out:
# [                  CORESTICKM159SFRBATL
#  observation_date
#  1968-01-01                    3.651861
#  1968-02-01                    3.673819
#  ...                                ...
#  2026-03-01                    2.929321
#  2026-04-01                    3.038932
#
#  [700 rows x 1 columns],
#                    MORTGAGE30US
#  observation_date
#  1971-04-02                7.33
#  1971-04-09                7.31
#  ...                        ...
#  2026-05-07                6.37
#  2026-05-14                6.36
#
#  [2877 rows x 1 columns],
#                    FEDFUNDS
#  observation_date
#  1954-07-01            0.80
#  1954-08-01            1.22
#  ...                    ...
#  2026-03-01            3.64
#  2026-04-01            3.64
#
#  [862 rows x 1 columns],
#                    T10YIE
#  observation_date
#  2021-05-17          2.54
#  2021-05-18          2.52
#  ...                  ...
#  2026-05-14          2.47
#  2026-05-15          2.49
#
# ...

# %%
pdfs_concat = pd.concat(pdfs, axis=1, join='outer')
pdfs_concat.tail(20).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b24c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b24c_level0_col0" class="col_heading level0 col0" >CORESTICKM159SFRBATL</th>
#       <th id="T_2b24c_level0_col1" class="col_heading level0 col1" >MORTGAGE30US</th>
#       <th id="T_2b24c_level0_col2" class="col_heading level0 col2" >FEDFUNDS</th>
#       <th id="T_2b24c_level0_col3" class="col_heading level0 col3" >T10YIE</th>
#       <th id="T_2b24c_level0_col4" class="col_heading level0 col4" >UNRATE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >observation_date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
pdfs_interpl = pdfs_concat.interpolate(method='linear')
pdfs_interpl.tail(20).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac91a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac91a_level0_col0" class="col_heading level0 col0" >CORESTICKM159SFRBATL</th>
#       <th id="T_ac91a_level0_col1" class="col_heading level0 col1" >MORTGAGE30US</th>
#       <th id="T_ac91a_level0_col2" class="col_heading level0 col2" >FEDFUNDS</th>
#       <th id="T_ac91a_level0_col3" class="col_heading level0 col3" >T10YIE</th>
#       <th id="T_ac91a_level0_col4" class="col_heading level0 col4" >UNRATE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >observation_date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
pdfs_interpl.plot(title = 'FRED Data - multiple datasets, liner interplotated')

# %% [markdown]
# ## Export data

# %%
pdfs_interpl.index.name = 'date'
pdfs_interpl
# Out:
#             CORESTICKM159SFRBATL  MORTGAGE30US  FEDFUNDS  T10YIE  UNRATE
# date
# 1948-01-01                   NaN           NaN       NaN     NaN     3.4
# 1948-02-01                   NaN           NaN       NaN     NaN     3.8
# ...                          ...           ...       ...     ...     ...
# 2026-05-14              3.038932          6.36      3.64    2.47     4.3
# 2026-05-15              3.038932          6.36      3.64    2.49     4.3
#
# [4739 rows x 5 columns]

# %%
pdfs_interpl_renamed = pdfs_interpl.rename(columns={
    'CORESTICKM159SFRBATL': 'CPI',
    'MORTGAGE30US': 'MR',
    'FEDFUNDS': 'FFR',
    'T10YIE': 'INF10',
    'UNRATE': 'UNRT'
})
pdfs_interpl_renamed
# Out:
#                  CPI    MR   FFR  INF10  UNRT
# date
# 1948-01-01       NaN   NaN   NaN    NaN   3.4
# 1948-02-01       NaN   NaN   NaN    NaN   3.8
# ...              ...   ...   ...    ...   ...
# 2026-05-14  3.038932  6.36  3.64   2.47   4.3
# 2026-05-15  3.038932  6.36  3.64   2.49   4.3
#
# [4739 rows x 5 columns]

# %%
pdfs_interpl_renamed.plot(title = 'FRED Data - PDFS Liner Interpl renamed')

# %%
pdfs_interpl_renamed.to_csv('../../data/data_FRED/FRED_joined.csv')
pdfs_interpl_renamed.to_parquet('../../data/data_FRED/FRED_joined.parquet')

# %%
pd.read_parquet('../../data/data_FRED/FRED_joined.parquet')
# Out:
#                  CPI    MR   FFR  INF10  UNRT
# date
# 1948-01-01       NaN   NaN   NaN    NaN   3.4
# 1948-02-01       NaN   NaN   NaN    NaN   3.8
# ...              ...   ...   ...    ...   ...
# 2026-05-14  3.038932  6.36  3.64   2.47   4.3
# 2026-05-15  3.038932  6.36  3.64   2.49   4.3
#
# [4739 rows x 5 columns]

# %%
# pip install openpyxl ## in Terminal Window
# import openpyxl

pdfs_interpl_renamed.to_excel('../../data/data_FRED/FRED_joined.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 2
#       1 # pip install openpyxl ## in Terminal Window
# ----> 2 import openpyxl
#       4 pdfs_interpl_renamed.to_excel('../../data/data_FRED/FRED_joined.xlsx')
#
# ModuleNotFoundError: No module named 'openpyxl'
